# %%
# !pip install -q bamboolib
# !python -m bamboolib install_labextensions
# Out:
# Trying to install bamboolib labextensions...
# Installing ipyslickgrid: ... done
# Installing plotlywidget@4.14.3: ... done
# Installing jupyterlab-plotly@4.14.3: ... done
# Installing bamboolib@1.26.0: ... done
# Starting JupyterLab build. This may take a while ...
# Building jupyterlab assets (production, minimized)
# Successfully built JupyterLab
#
# Please reload your Jupyter Lab browser window

# %%
import pandas as pd

# %%
items = pd.read_csv('../data/preprocessed/items.csv')
users = pd.read_csv('../data/preprocessed/users.csv')

# %%
items
# Out:
#        item_id content_type                 title      title_orig  \
# 0        10711         film        поговори с ней  Hable con ella
# 1         2508         film           голые перцы    Search Party
# 2        10716         film      тактическая сила  Tactical Force
# 3         7868         film                45 лет        45 Years
# 4        16268         film  все решает мгновение            None
# ...        ...          ...                   ...             ...
# 15958     6443       series         полярный круг   Arctic Circle
# 15959     2367       series               надежда            None
# 15960    10632       series                сговор          Hassel
# 15961     4538       series          среди камней      Darklands
# 15962     3206       series                  гоша            None
#
#        release_year                                            genres  \
# 0            2002.0           драмы, зарубежные, детективы, мелодрамы
# ...

# %%
users.loc[(users.age == 'age_25_34') | (users.age == 'age_45_54')]
# Out:
#         user_id        age        income sex  kids_flg
# 0        973171  age_25_34  income_60_90   М         1
# 2       1047345  age_45_54  income_40_60   Ж         0
# 3        721985  age_45_54  income_20_40   Ж         0
# 5       1037719  age_45_54  income_60_90   М         0
# 6        391756  age_25_34   income_0_20   М         0
# ...         ...        ...           ...  ..       ...
# 840185  1021814  age_45_54  income_20_40   Ж         0
# 840186    80113  age_25_34  income_40_60   Ж         0
# 840189   191349  age_45_54  income_40_60   М         1
# 840190   393868  age_25_34  income_20_40   М         0
# 840191   365945  age_25_34  income_20_40   Ж         0
#
# [369851 rows x 5 columns]

# %%
interactions = pd.read_csv('../data/preprocessed/interactions.csv')

# %%
interactions.groupby('watched_pct')['item_id'].count()
# Out:
# watched_pct
# 0       728579
# 1       285565
# 2       168206
# 3       115915
# 4        92151
#         ...
# 96       52185
# 97       46225
# 98       38066
# 99       33428
# 100    1407197
# Name: item_id, Length: 101, dtype: int64

# %%
items['keywords'][0]
# Out:
# 'Поговори, ней, 2002, Испания, друзья, любовь, сильные, женщины, преодоление, трудностей, отношения, дружба, отношения, паре, отношения, мужчины, женщины, романтические, отношения, потеря, близких, флешбек, видения, несчастный, случай, разговоры, любовники, кома'

# %%
items = pd.read_csv('../data/raw/items.csv')
users = pd.read_csv('../data/raw/users.csv')
interactions = pd.read_csv('../data/raw/interactions.csv')

# %% [markdown]
# **items**
#
# - 19k items
# - 2 types: film / series
# - release year
#     - most popular: 2017-2019, 2014-2016
#     - unique: 105
#     - missing: 98
# - genres
#     - unique: 2771
#     - missing: 0
# - countries
#     - unique: 687
#     - missing: 37
#     - most popular: russia, usa
# - for kids
#     - unique: 2
#     - missing: 15k (96%) (can be recreated with genres "для детей", not "ужасы" etc or age_rating)
# - age rating
#     - unique: 6
#     - missing: 2 (can be filled manually)
# - studios
#     - unique: 38
#     - most popualar: hbo
#     - missing: 14k (can't be easily recreated)
# - directors
#     - unique: 8k
#     - missing: 9.5% (1.5k)
#     - most popular: оливье шиабоду (3.5%)
# - actors
#     - unique: 13k
#     - missing: 2.6k (16%)
# - keywords:
#     - unique: 15k
#     - missing: 423 (can be filled content type etc)
#
# ---
#
# **users**
#
# - 840k users
# - age
#     - binned: 6 groups
#     - most popular: 25-34
#     - missing: 2%
# - income
#     - binned: 6 groups
#     - most popular: 20-40
#     - missing: 2%
# - sex
#     - unique: 2 (50/50)
#     - missing: 2%
# - kids flag
#     - unique: 2 (0=70%, 1=30%)
#     - missing: 0%
#
# ---
#
# **interactions**
#
# - user_id: 962k
# - item_id:

# %%
print(
    items['age_rating'].unique().tolist()
)

print('\n\n', items.columns)
# Out:
# [16.0, 12.0, 6.0, 18.0, 0.0, 21.0, nan]
#
#
#  Index(['item_id', 'content_type', 'title', 'title_orig', 'release_year',
#        'genres', 'countries', 'for_kids', 'age_rating', 'studios', 'directors',
#        'actors', 'description', 'keywords'],
#       dtype='object')

# %%
items
# Out:
#        item_id content_type                 title      title_orig  \
# 0        10711         film        Поговори с ней  Hable con ella
# 1         2508         film           Голые перцы    Search Party
# 2        10716         film      Тактическая сила  Tactical Force
# 3         7868         film                45 лет        45 Years
# 4        16268         film  Все решает мгновение             NaN
# ...        ...          ...                   ...             ...
# 15958     6443       series         Полярный круг   Arctic Circle
# 15959     2367       series               Надежда             NaN
# 15960    10632       series                Сговор          Hassel
# 15961     4538       series          Среди камней      Darklands
# 15962     3206       series                  Гоша             NaN
#
#        release_year                                            genres  \
# 0            2002.0           драмы, зарубежные, детективы, мелодрамы
# ...

# %%
merged = pd.merge(
    left=interactions,
    right=items,
    on=['item_id']
)

merged
# Out:
#          user_id  item_id last_watch_dt  total_dur  watched_pct content_type  \
# 0         176549     9506    2021-05-11       4250           72         film
# 1         964868     9506    2021-04-30       6725          100         film
# 2         450170     9506    2021-07-18        848           14         film
# 3         683820     9506    2021-06-28       2617           44         film
# 4         547714     9506    2021-08-07       5494           93         film
# ...          ...      ...           ...        ...          ...          ...
# 5476246   666766     7833    2021-03-14          6            0         film
# 5476247   352033     9125    2021-05-12       4431           19       series
# 5476248   258949    10064    2021-04-28     127850          100       series
# 5476249   846909    13019    2021-03-13         10            0         film
# 5476250   740277    10542    2021-04-04        792          100         film
#
# ...

# %%
v = merged['release_year'].value_counts()

(v / v.sum() * 100).cumsum()
# Out:
# 2021.0     25.272069
# 2020.0     39.140244
# 2019.0     49.385117
# 2018.0     56.548286
# 2017.0     62.260286
#              ...
# 1925.0     99.999708
# 1917.0     99.999817
# 1897.0     99.999909
# 1918.0     99.999982
# 1921.0    100.000000
# Name: release_year, Length: 105, dtype: float64

# %%
interactions['total_dur'].quantile(0.75)
# Out:
# 7116.0

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
items.groupby9

# %%
users.dtypes
# Out:
# user_id      int64
# age         object
# income      object
# sex         object
# kids_flg     int64
# dtype: object

# %%
users
# Out:
#         user_id         age        income  sex  kids_flg
# 0        973171   age_25_34  income_60_90    М         1
# 1        962099   age_18_24  income_20_40    М         0
# 2       1047345   age_45_54  income_40_60    Ж         0
# 3        721985   age_45_54  income_20_40    Ж         0
# 4        704055   age_35_44  income_60_90    Ж         0
# ...         ...         ...           ...  ...       ...
# 840192   339025  age_65_inf   income_0_20    Ж         0
# 840193   983617   age_18_24  income_20_40    Ж         1
# 840194   251008         NaN           NaN  NaN         0
# 840195   590706         NaN           NaN    Ж         0
# 840196   166555  age_65_inf  income_20_40    Ж         0
#
# [840197 rows x 5 columns]

# %%
users['kids_flg'].unique().tolist()
# Out:
# [1, 0]

# %%
enc.categories_
# Out:
# [array(['Ж', 'М', nan], dtype=object)]

# %%
interactions
# Out:
#          user_id  item_id last_watch_dt  total_dur  watched_pct
# 0         176549     9506    2021-05-11       4250         72.0
# 1         699317     1659    2021-05-29       8317        100.0
# 2         656683     7107    2021-05-09         10          0.0
# 3         864613     7638    2021-07-05      14483        100.0
# 4         964868     9506    2021-04-30       6725        100.0
# ...          ...      ...           ...        ...          ...
# 5476246   648596    12225    2021-08-13         76          0.0
# 5476247   546862     9673    2021-04-13       2308         49.0
# 5476248   697262    15297    2021-08-20      18307         63.0
# 5476249   384202    16197    2021-04-19       6203        100.0
# 5476250   319709     4436    2021-08-15       3921         45.0
#
# [5476251 rows x 5 columns]

# %%
def test(segs, d):
    
    yield list(zip(a, b))

a = {
    'a': ['a1', 'a2'],
    'b': ['b1', 'b2', 'b3']
    'c': ['c1']
}
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %%
from itertools import product

list(product([1, 2, 3], ['a', 'b'], ['z']))
# Out:
# [(1, 'a', 'z'),
#  (1, 'b', 'z'),
#  (2, 'a', 'z'),
#  (2, 'b', 'z'),
#  (3, 'a', 'z'),
#  (3, 'b', 'z')]

# %%
from functools import partial

def test(a, b, c):
    return a+b+c

f = partial(test, a=1)
f2 = partial(f, b=2)

f2(c=1)
# Out:
# 4

# %%
class Test:
    def __init__(self):
        self.__t = 'a'

class Test2:
    
    def __init__(self):
        self.t = Test()
    
    def test(self):
        return self.t.__t

t = Test2()
t.test()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_q/4c1b53g15wq20l6zfhthblz80000gp/T/ipykernel_91339/2003580001.py in <module>
#      12
#      13 t = Test2()
# ---> 14 t.test()
#
# /var/folders/_q/4c1b53g15wq20l6zfhthblz80000gp/T/ipykernel_91339/2003580001.py in test(self)
#       9
#      10     def test(self):
# ---> 11         return self.t.__t
#      12
#      13 t = Test2()
#
# AttributeError: 'Test' object has no attribute '_Test2__t'

# %%
# !pip install more-itertools
# Out:
# ...
#      |████████████████████████████████| 54 kB 1.4 MB/s
# ...

# %%
from more_itertools import pairwise

list(pairwise([1, 3, 9]))
# Out:
# [(1, 3), (3, 9)]
